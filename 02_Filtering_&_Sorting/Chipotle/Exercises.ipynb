# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %%
dfchipo=pd.read_csv(r"https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", sep="\t")

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
dfchipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
dfchipo.item_price=dfchipo.item_price.str.replace(pat="$",repl="",regex=True).astype(float)

# %%
dfchipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
dfchipo[dfchipo.item_price>10]
# Out:
#       order_id  quantity           item_name  \
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# 13           7         1        Chicken Bowl
# 23          12         1     Chicken Burrito
# ...        ...       ...                 ...
# 4610      1830         1       Steak Burrito
# 4611      1830         1      Veggie Burrito
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 23    [[Tomatillo-Green Chili Salsa (Medium), Tomati...       10.98
# ...

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
dfchipo[["item_name","item_price"]]
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# ...                                     ...         ...
# 4617                          Steak Burrito       11.75
# 4618                          Steak Burrito       11.75
# 4619                     Chicken Salad Bowl       11.25
# 4620                     Chicken Salad Bowl        8.75
# 4621                     Chicken Salad Bowl        8.75
#
# [4622 rows x 2 columns]

# %%
dfchipo[["item_name","item_price"]].drop_duplicates()
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# ...                                     ...         ...
# 4237                    Chips and Guacamole        8.50
# 4354                       Steak Soft Tacos       18.50
# 4489                    Chips and Guacamole       17.80
# 4509                                  Chips        1.99
# 4510                          Barbacoa Bowl       11.49
#
# [209 rows x 2 columns]

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
dfchipo.sort_values("item_name", ascending=True)
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description  item_price
# 3389                                        [Diet Coke]       12.98
# 341                                         [Diet Coke]        6.49
# 1849                                             [Coke]        6.49
# 1860                                        [Diet Coke]        6.49
# 2713                                             [Coke]        6.49
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
dfchipo.sort_values("item_price")
# Out:
#       order_id  quantity                     item_name  \
# 1140       471         1                 Bottled Water
# 821        338         1                   Canned Soda
# 3926      1575         1                   Canned Soda
# 107         47         1                   Canned Soda
# 2562      1014         1                   Canned Soda
# ...        ...       ...                           ...
# 3601      1443         3                Veggie Burrito
# 3602      1443         4               Chicken Burrito
# 1254       511         4               Chicken Burrito
# 3480      1398         3                 Carnitas Bowl
# 3598      1443        15  Chips and Fresh Tomato Salsa
#
#                                      choice_description  item_price
# 1140                                                NaN        1.09
# 821                                         [Coca Cola]        1.09
# 3926                                       [Dr. Pepper]        1.09
# ...

# %%
dfchipo.sort_values("item_price", ascending=False).head(1)
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
dfchipo.item_name
# Out:
# 0                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 2                            Nantucket Nectar
# 3       Chips and Tomatillo-Green Chili Salsa
# 4                                Chicken Bowl
#                         ...
# 4617                            Steak Burrito
# 4618                            Steak Burrito
# 4619                       Chicken Salad Bowl
# 4620                       Chicken Salad Bowl
# 4621                       Chicken Salad Bowl
# Name: item_name, Length: 4622, dtype: object

# %%
dfchipo[dfchipo.item_name == "Veggie Salad Bowl"]
# Out:
#       order_id  quantity          item_name  \
# 186         83         1  Veggie Salad Bowl
# 295        128         1  Veggie Salad Bowl
# 455        195         1  Veggie Salad Bowl
# 496        207         1  Veggie Salad Bowl
# 960        394         1  Veggie Salad Bowl
# 1316       536         1  Veggie Salad Bowl
# 1884       760         1  Veggie Salad Bowl
# 2156       869         1  Veggie Salad Bowl
# 2223       896         1  Veggie Salad Bowl
# 2269       913         1  Veggie Salad Bowl
# 2683      1066         1  Veggie Salad Bowl
# 3223      1289         1  Veggie Salad Bowl
# 3293      1321         1  Veggie Salad Bowl
# 4109      1646         1  Veggie Salad Bowl
# 4201      1677         1  Veggie Salad Bowl
# 4261      1700         1  Veggie Salad Bowl
# 4541      1805         1  Veggie Salad Bowl
# 4573      1818         1  Veggie Salad Bowl
#
#                                      choice_description  item_price
# ...

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
dfchipo[dfchipo.quantity>1]
# Out:
#       order_id  quantity           item_name  \
# 4            2         2        Chicken Bowl
# 18           9         2         Canned Soda
# 51          23         2         Canned Soda
# 135         60         2  Chicken Salad Bowl
# 148         67         2       Steak Burrito
# ...        ...       ...                 ...
# 4491      1786         4   Canned Soft Drink
# 4499      1789         2   Canned Soft Drink
# 4560      1812         2   Canned Soft Drink
# 4561      1813         2  Chicken Salad Bowl
# 4582      1822         2       Bottled Water
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 18                                             [Sprite]        2.18
# 51                                       [Mountain Dew]        2.18
# 135   [Tomatillo Green Chili Salsa, [Sour Cream, Che...       22.50
# 148   [Tomatillo-Red Chili Salsa (Hot), [Rice, Chees...       17.98
# ...

# %%
dfchipo[dfchipo.item_name == "Canned Soda"]
# Out:
#       order_id  quantity    item_name choice_description  item_price
# 18           9         2  Canned Soda           [Sprite]        2.18
# 28          14         1  Canned Soda       [Dr. Pepper]        1.09
# 51          23         2  Canned Soda     [Mountain Dew]        2.18
# 53          24         1  Canned Soda           [Sprite]        1.09
# 107         47         1  Canned Soda       [Dr. Pepper]        1.09
# ...        ...       ...          ...                ...         ...
# 3897      1562         1  Canned Soda     [Mountain Dew]        1.09
# 3926      1575         1  Canned Soda       [Dr. Pepper]        1.09
# 3936      1578         1  Canned Soda  [Diet Dr. Pepper]        1.09
# 4008      1604         1  Canned Soda        [Diet Coke]        1.09
# 4051      1621         1  Canned Soda           [Sprite]        1.09
#
# [104 rows x 5 columns]

# %%
dfchipo[["quantity","item_name"]]
# Out:
#       quantity                              item_name
# 0            1           Chips and Fresh Tomato Salsa
# 1            1                                   Izze
# 2            1                       Nantucket Nectar
# 3            1  Chips and Tomatillo-Green Chili Salsa
# 4            2                           Chicken Bowl
# ...        ...                                    ...
# 4617         1                          Steak Burrito
# 4618         1                          Steak Burrito
# 4619         1                     Chicken Salad Bowl
# 4620         1                     Chicken Salad Bowl
# 4621         1                     Chicken Salad Bowl
#
# [4622 rows x 2 columns]

# %%
dfchipo[(dfchipo.item_name=="Canned Soda") & (dfchipo.quantity > 1)]
# Out:
#       order_id  quantity    item_name choice_description  item_price
# 18           9         2  Canned Soda           [Sprite]        2.18
# 51          23         2  Canned Soda     [Mountain Dew]        2.18
# 162         73         2  Canned Soda        [Diet Coke]        2.18
# 171         76         2  Canned Soda  [Diet Dr. Pepper]        2.18
# 350        150         2  Canned Soda        [Diet Coke]        2.18
# 352        151         2  Canned Soda        [Coca Cola]        2.18
# 698        287         2  Canned Soda        [Coca Cola]        2.18
# 700        288         2  Canned Soda        [Coca Cola]        2.18
# 909        376         2  Canned Soda     [Mountain Dew]        2.18
# 1091       450         2  Canned Soda       [Dr. Pepper]        2.18
# 1092       450         2  Canned Soda        [Coca Cola]        2.18
# 1944       787         2  Canned Soda       [Dr. Pepper]        2.18
# 2135       859         2  Canned Soda        [Diet Coke]        2.18
# ...

# %%
dfchipo.query('item_name == Canned Soda & quantity >1')
# Out:
# Traceback (most recent call last):
#
#   File ~\miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3369 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Input In [137] in <cell line: 1>
#     dfchipo.query('item_name == Canned Soda & quantity >1')
#
#   File ~\miniconda3\lib\site-packages\pandas\core\frame.py:4111 in query
#     res = self.eval(expr, **kwargs)
#
#   File ~\miniconda3\lib\site-packages\pandas\core\frame.py:4240 in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File ~\miniconda3\lib\site-packages\pandas\core\computation\eval.py:350 in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#
#   File ~\miniconda3\lib\site-packages\pandas\core\computation\expr.py:811 in __init__
#     self.terms = self.parse()
#
#   File ~\miniconda3\lib\site-packages\pandas\core\computation\expr.py:830 in parse
#     return self._visitor.visit(self.expr)
#
# ...

# %% [markdown]
# **DUDAS**

# %% [markdown]
# *-Diferencia entre clase y función*

# %% [markdown]
# La clase tiene mayusculas y la función no.

# %% [markdown]
# *-Dataframe*

# %% [markdown]
# Algunas funciones solo funcionan con objetos y no listas, por ejemplo la media.
# Hay que crear data frame  apartir de listas.

# %% [markdown]
# Is not callable --> no se puede llamar a un objeto si previamente no se ha creado una función.

# %% [markdown]
# *-Crear una clase*

# %% [markdown]
# df = pd.DataFrame(raw_data)

# %% [markdown]
# class DataFrame():
#    def __init__(self):   #self se utiliza para referirte a la instancia que aun no has creado#
#    self.size= 89

# %% [markdown]
# Para poder cambiar el tamaño (size) del DataFrame:
# class DataFrame():
#    def __init__(self):
#    self.size= 89
#    def cambiar_size(self,nuevo_tamaño):
#    self.size = nuevo_tamaño

# %% [markdown]
# ren.cambiar_size(90)

# %% [markdown]
# *-.loc vs [][  ]*

# %% [markdown]
# mask = df.Team.isin(["Italy", "Spain"])

# %% [markdown]
# df=df.set_index(keys="Team")

# %% [markdown]
# df.loc[["Italy","Spain"],["Yellow card", "Red card"]]

# %% [markdown]
# Diferencia entre iloc y loc --> iloc solo va con numeros enteros (integer loc)

# %% [markdown]
# **Comillas dobles o simple**

# %%
df.query()
